# %%
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client
import warnings
warnings.filterwarnings("ignore")

# %%
cluster = PBSCluster(
    project='P93300313',
    job_name = 'test',
    cores = 1,
    memory = '100GiB',
    processes = 1,
    local_directory = '/glade/derecho/scratch/jaye/dask/pbs.$PBS_JOBID/dask/spill',
    resource_spec = 'select=1:ncpus=1:mem=100GB',
    queue = 'casper',
    walltime = '02:00:00',
    interface = 'ext'
)

# %%
cluster.scale(jobs=50)

# %%
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://128.117.208.109:45461' processes=0 threads=0, memory=0 B>

# %%
print(cluster.job_script())
# Out:
# #!/usr/bin/env bash
#
# #PBS -N test
# #PBS -q casper
# #PBS -A P93300313
# #PBS -l select=1:ncpus=1:mem=100GB
# #PBS -l walltime=02:00:00
#
# /glade/work/jaye/conda-envs/npl_climpred3/bin/python -m distributed.cli.dask_worker tcp://128.117.208.109:45461 --nthreads 1 --memory-limit 100.00GiB --name dummy-name --nanny --death-timeout 60 --local-directory /glade/derecho/scratch/jaye/dask/pbs.$PBS_JOBID/dask/spill --interface ext

# %%
cluster.dashboard_link
# Out:
# 'https://jupyterhub.hpc.ucar.edu/stable/user/jaye/proxy/38385/status'

# %%
cluster.close()
# Out:
# 2025-01-17 15:05:13,007 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
