# %% [markdown]
# # Create masked data for countries or regions
#
# ---
#
# This notebook will create masked data (1D instead of 2D lat/lon) that are regional averages. You can run this on any of the files we have created so far. The country data that has already been run is available.
#
# If you want other regions you can download shapefiles to use. Information on `regionmask` can be found here:
#
# https://regionmask.readthedocs.io/en/stable/

# %%
# !pip install intake-geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: intake-geopandas in /glade/u/home/berner/.local/lib/python3.9/site-packages (0.2.4)
# Requirement already satisfied: geopandas in /glade/u/home/berner/.local/lib/python3.9/site-packages (from intake-geopandas) (0.9.0)
# Requirement already satisfied: intake in /glade/u/home/berner/.local/lib/python3.9/site-packages (from intake-geopandas) (0.6.2)
# Requirement already satisfied: shapely>=1.6 in /glade/u/home/berner/.local/lib/python3.9/site-packages (from geopandas->intake-geopandas) (1.7.1)
# Requirement already satisfied: pandas>=0.24.0 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from geopandas->intake-geopandas) (1.2.4)
# Requirement already satisfied: fiona>=1.8 in /glade/u/home/berner/.local/lib/python3.9/site-packages (from geopandas->intake-geopandas) (1.8.20)
# Requirement already satisfied: pyproj>=2.2.0 in /glade/u/home/berner/.local/lib/python3.9/site-packages (from geopandas->intake-geopandas) (3.1.0)
# Requirement already satisfied: munch in /glade/u/home/berner/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in /glade/u/home/berner/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (0.7.2)
# Requirement already satisfied: attrs>=17 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (21.2.0)
# Requirement already satisfied: click>=4.0 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (8.0.1)
# Requirement already satisfied: setuptools in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (49.6.0.post20210108)
# Requirement already satisfied: click-plugins>=1.0 in /glade/u/home/berner/.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (1.1.1)
# Requirement already satisfied: certifi in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from fiona>=1.8->geopandas->intake-geopandas) (2021.5.30)
# Requirement already satisfied: python-dateutil>=2.7.3 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from pandas>=0.24.0->geopandas->intake-geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from pandas>=0.24.0->geopandas->intake-geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from pandas>=0.24.0->geopandas->intake-geopandas) (1.20.3)
# Requirement already satisfied: jinja2 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from intake->intake-geopandas) (3.0.1)
# Requirement already satisfied: pyyaml in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from intake->intake-geopandas) (5.4.1)
# Requirement already satisfied: dask in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from intake->intake-geopandas) (2021.6.0)
# Requirement already satisfied: entrypoints in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from intake->intake-geopandas) (0.3)
# Requirement already satisfied: appdirs in /glade/u/home/berner/.local/lib/python3.9/site-packages (from intake->intake-geopandas) (1.4.4)
# Requirement already satisfied: fsspec>=0.7.4 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from intake->intake-geopandas) (2021.6.0)
# Requirement already satisfied: toolz>=0.8.2 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from dask->intake->intake-geopandas) (0.11.1)
# Requirement already satisfied: partd>=0.3.10 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from dask->intake->intake-geopandas) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from dask->intake->intake-geopandas) (1.6.0)
# Requirement already satisfied: locket in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from partd>=0.3.10->dask->intake->intake-geopandas) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /glade/u/ssg/ch/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20210616/lib/python3.9/site-packages (from jinja2->intake->intake-geopandas) (2.0.1)

# %%
import cftime
import numpy as np
import xarray as xr
xr.set_options(keep_attrs=True)
import climpred
from tqdm import tqdm
import dask.array as da
import matplotlib.pyplot as plt
from matplotlib.ticker import FixedLocator
import xskillscore as xs
import regionmask
import intake
import intake_geopandas
import warnings
warnings.filterwarnings("ignore")

from dask.distributed import Client
import dask.config
dask.config.set({"array.slicing.split_large_chunks": False})

# %%
client = Client("tcp://10.12.206.46:41051")

# %% [markdown]
# Choose your model, data type, and time

# %%
model = "ECMWF" #OBS, ECMWF, NCEP, or ECCC
data = "climatology" #raw or anom or climatology
time = "biweekly" #biweekly or daily

# %%
#hinda = xr.open_zarr("/glade/campaign/mmm/c3we/jaye/S2S_zarr/"+model+"."+data+".cat_edges."+time+".geospatial.zarr/", consolidated=True).astype('float32')
hinda = xr.open_zarr("/glade/campaign/mmm/c3we/jaye/S2S_zarr/"+model+"."+data+"."+time+".geospatial.zarr/", consolidated=True).astype('float32')
cat = intake.open_catalog('https://raw.githubusercontent.com/aaronspring/remote_climate_data/master/master.yaml')

# %%
pip install aiohttp
# Out:
# Requirement already satisfied: aiohttp in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (3.7.4.post0)
# Requirement already satisfied: attrs>=17.3.0 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from aiohttp) (21.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from aiohttp) (3.10.0.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from aiohttp) (4.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from aiohttp) (1.6.3)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from aiohttp) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from aiohttp) (5.1.0)
# Requirement already satisfied: idna>=2.0 in /glade/work/berner/miniconda3/envs/s2s-asp/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
hinda
# Out:
# <xarray.Dataset>
# Dimensions:    (dayofyear: 97, lat: 121, lead: 3, lon: 240)
# Coordinates:
#   * dayofyear  (dayofyear) int64 2 9 16 23 30 37 44 ... 351 352 358 359 365 366
#   * lat        (lat) float64 90.0 88.5 87.0 85.5 ... -85.5 -87.0 -88.5 -90.0
#   * lead       (lead) timedelta64[ns] 1 days 15 days 31 days
#   * lon        (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 354.0 355.5 357.0 358.5
# Data variables:
#     gh_500     (lead, dayofyear, lat, lon) float32 dask.array<chunksize=(3, 1, 121, 240), meta=np.ndarray>
#     t2m        (lead, dayofyear, lat, lon) float32 dask.array<chunksize=(3, 1, 121, 240), meta=np.ndarray>
#     tp         (lead, dayofyear, lat, lon) float32 dask.array<chunksize=(3, 1, 121, 240), meta=np.ndarray>
# Attributes: (12/31)
#     GRIB_NV:                                  0
#     GRIB_Nx:                                  240
#     GRIB_Ny:                                  121
#     GRIB_cfName:                              air_temperature
#     GRIB_cfVarName:                           t2m
#     GRIB_dataType:                            pf
#     ...                                       ...
#     GRIB_typeOfLevel:                         heightAboveGround
#     GRIB_units:                               K
#     cell_method:                              lead_time: average
#     long_name:                                2 metre temperature
#     standard_name:                            air_temperature
#     units:                                    K

# %% [markdown]
# I understand this is messy, but we need to rechunk for each different type of data. It's a bit too messy for lots of if statements, so just read my comments and choose wisely. Or just try multiple times until it works :)

# %%
#hinda = hinda.chunk({"member": "auto", "init": -1, "lead": "auto", "lat": 45, "lon": 60}).persist() #hindcast raw & anom
#hinda = hinda.chunk({"time": -1, "lat": 45, "lon": 60}).persist() #verif
hinda = hinda.chunk({"dayofyear": -1, "lead": "auto", "lat": 45, "lon": 60}).persist() #climatology for the models
#hinda = hinda.chunk({"dayofyear": -1, "lat": 45, "lon": 60}).persist() #climatology for verification
#hinda = hinda.chunk({"category_edge": -1, "dayofyear": -1, "lead": "auto", "lat": 45, "lon": 60}).persist() #cat_edges for the model
#hinda = hinda.chunk({"category_edge": -1, "dayofyear": -1, "lat": 45, "lon": 60}).persist() #cat_edges for verification

# %% [markdown]
# Here we are seeing what Countries are available for masking. Just listing them out.

# %%
region = cat.regionmask.Countries.read()
region
# Out:
# <regionmask.Regions>
# Name:     unnamed
#
# Regions:
#   0         Ind0                   Indonesia
#   1         Mal0                    Malaysia
#   2          Chi                       Chile
#   3          Bol                     Bolivia
#   4          Per                        Peru
# ..           ...                         ...
# 250          Mac                       Macau
# 251 AshandCarIsl Ashmore and Cartier Islands
# 252    BajNueBan             Bajo Nuevo Bank
# 253       SerBan             Serranilla Bank
# 254       ScaSho           Scarborough Shoal
#
# [255 regions]

# %% [markdown]
# ## Running the region mask over the data!

# %%
mask = region.mask(hinda, lon_name='lon',lat_name='lat')

# %%
var = hinda.groupby(mask).mean('stacked_lat_lon')

# %% [markdown]
# Here we have a function that adds labels to the region mask.

# %%
def set_regionmask_labels(ds, region):
    """Set names as region label for region dimension from regionmask regions."""
    abbrevs = region[ds.region.values].abbrevs
    names = region[ds.region.values].names
    ds.coords["abbrevs"] = ("region", abbrevs)
    ds.coords["number"] = ("region", ds.region.values)
    ds["region"] = names
    return ds

var = set_regionmask_labels(var, region)
var.coords

# %%
var

# %% [markdown]
# Again, here you need to choose which chunking you want based on your data.

# %%
#%time var = var.chunk({"member": -1, "init": -1, "lead": -1, "region": 1}).persist() #hindcast
#%time var = var.chunk({"member": -1, "init": -1, "lead": "auto", "region": 1}).persist() #hindcast
#%time var = var.chunk({"time": -1, "region": 1}).persist() #verif
#%time var = var.chunk({"dayofyear": -1, "lead": -1, "region": 1}).persist() #climatology for the models
#%time var = var.chunk({"dayofyear": -1, "region": 1}).persist() #climatology for verification
#%time var = var.chunk({"category_edge": -1, "dayofyear": -1, "lead": -1, "region": 1}).persist() #cat_edges for the models
# %time var = tsurfc.chunk({"category_edge": -1, "dayofyear": -1, "region": 1}).persist() #cat_edges for verification

# %%
var

# %% [markdown]
# # Write out to zarr!
#
# Or even netcdf if you want. The data is small enough

# %%
# %time var.to_zarr("/glade/campaign/mmm/c3we/jaye/S2S_zarr/"+model+"."+data+".cat_edges."+time+".country.zarr/",mode="w",consolidated=True)
