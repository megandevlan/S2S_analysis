# %%
from xarray.core.dataarray import DataArray
import metpy.constants as mpconsts
import numpy as np
from metpy import calc as mpcalc
from metpy.interpolate import log_interpolate_1d as log_interp_1d
from metpy.units import units
import os
from pandas.core.series import Series
from xarray.core.dataarray import DataArray
from tqdm import tqdm


import os
import glob
import numpy as np 
import xarray as xr
import pandas as pd
import datetime
from datetime import date, timedelta
import dask
import metpy as mp
from metpy.units import units
import metpy.calc as mpc
import Ngl

# Plotting utils 
import matplotlib
import matplotlib.pyplot as plt 
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.util

# %%
# Grabbed from Brian M. to use time midpoints, not end periods
def cesm_correct_time(ds):
    """Given a Dataset, check for time_bnds,
       and use avg(time_bnds) to replace the time coordinate.
       Purpose is to center the timestamp on the averaging inverval.   
       NOTE: ds should have been loaded using `decode_times=False`
    """
    assert 'time_bnds' in ds
    assert 'time' in ds
    correct_time_values = ds['time_bnds'].mean(dim='nbnd')
    # copy any metadata:
    correct_time_values.attrs = ds['time'].attrs
    ds = ds.assign_coords({"time": correct_time_values})
    ds = xr.decode_cf(ds)  # decode to datetime objects
    return ds

## Function to regrid data from ADF
def regrid_data(fromthis, tothis, method=1):
    """Regrid data using various different methods"""

    #Import necessary modules:
    import xarray as xr

    if method == 1:
        # kludgy: spatial regridding only, seems like can't automatically deal with time
        if 'time' in fromthis.coords:
            result = [fromthis.isel(time=t).interp_like(tothis) for t,time in enumerate(fromthis['time'])]
            result = xr.concat(result, 'time')
            return result
        else:
            return fromthis.interp_like(tothis)
    elif method == 2:
        newlat = tothis['lat']
        newlon = tothis['lon']
        coords = dict(fromthis.coords)
        coords['lat'] = newlat
        coords['lon'] = newlon
        return fromthis.interp(coords)
    elif method == 3:
        newlat = tothis['lat']
        newlon = tothis['lon']
        ds_out = xr.Dataset({'lat': newlat, 'lon': newlon})
        regridder = xe.Regridder(fromthis, ds_out, 'bilinear')
        return regridder(fromthis)
    elif method==4:
        # geocat
        newlat = tothis['lat']
        newlon = tothis['lon']
        result = geocat.comp.linint2(fromthis, newlon, newlat, False)
        result.name = fromthis.name
        
        return result

# - - - - - - - - - - - - - - - 
# Pre-process data while reading in 
# - - - - - - - - - - - - - - - 

def preprocess_atm(ds):
    ds         = cesm_correct_time(ds)
    dsSel      = ds[['SHFLX','LHFLX','PRECT']]
    # Also select spatial range
    dsSel = dsSel.sel(lat=slice(10,50), lon=slice(190,310))
    return dsSel

def preprocess_atm_profiles(ds):
    ds         = cesm_correct_time(ds)
    dsSel      = ds[['T','Q','PS','hyam','hyai','hybm','hybi','P0']]
    # Also select spatial range
    dsSel = dsSel.sel(lat=slice(10,50), lon=slice(190,310), lev=slice(500,1000))
    return dsSel


def interpolateToPressure(DS, varName, pressGoals):
    p0mb = DS.P0.values/100        # mb

    # Pull out hya/hyb profiles 
    hyam = np.squeeze(DS.hyam.values)[:]
    hybm = np.squeeze(DS.hybm.values)[:]
    hyai = np.squeeze(DS.hyai.values)[:]
    hybi = np.squeeze(DS.hybi.values)[:]

    # Surface pressure with time dimension
    PS   = DS.PS.values              # Pa 

    # Converting variables: 
    varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
    
    return varInterp

    
# # - - - - - - - - - - - - - - - 
# # Regrid utility 
# # - - - - - - - - - - - - - - - 
# def regrid_data(fromthis, tothis, method=1):
#     """Regrid data using various different methods"""

#     #Import necessary modules:
#     import xarray as xr

#     if method == 1:
#         # kludgy: spatial regridding only, seems like can't automatically deal with time
#         if 'time' in fromthis.coords:
#             result = [fromthis.isel(time=t).interp_like(tothis) for t,time in enumerate(fromthis['time'])]
#             result = xr.concat(result, 'time')
#             return result
#         else:
#             return fromthis.interp_like(tothis)
#     elif method == 2:
#         newlat = tothis['lat']
#         newlon = tothis['lon']
#         coords = dict(fromthis.coords)
#         coords['lat'] = newlat
#         coords['lon'] = newlon
#         return fromthis.interp(coords)
#     elif method == 3:
#         newlat = tothis['lat']
#         newlon = tothis['lon']
#         ds_out = xr.Dataset({'lat': newlat, 'lon': newlon})
#         regridder = xe.Regridder(fromthis, ds_out, 'bilinear')
#         return regridder(fromthis)
#     elif method==4:
#         # geocat
#         newlat = tothis['lat']
#         newlon = tothis['lon']
#         result = geocat.comp.linint2(fromthis, newlon, newlat, False)
#         result.name = fromthis.name
        
#         return result

# %%
def calc_ctp(pressure,temperature,start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,interp=False,db=False,plotskewt=False,plotdir="",station=""):

  """ Function for computing the Convective Triggering Potential
  Args:
      pressure (pint.Quantity): the vertical pressure profile
      temperature (pint.Quantity): the vertical temperature profile
      start_pressure_hpa (float, optional): the starting pressure to use. Default: -1 (bottom level in profile).
      bot_pressure_hpa (float, optional): bottom pressure value of the layer, added to start_pressure_hpa. Default: 100 hPa.
      top_pressure_hpa (float, optional): top pressure value of the layer, added to start_pressure_hpa. Default: 300 hPa.
      interp (bool): Whether to interpolate data to exact pressures or use the closest. Default: False.
      db (bool): Print debugging statements. Default: False
      plotskewt (bool): Plot a Skew-T Log-P graphic of the CTP calculation. Default: False.
      plotdir (string, optional): Directory where Skew-T plots should be written. Default: "".
      station (string, optional): Location ID string used for labeling the Skew-T plot and image file name. Default: "".
  Returns:
      float32
 
  Reference:
      TBD
  Notes:
      Lorem Ipsum
  """

  # Set a pressure difference for non-interpolation case
  # If the closest pressure to the bot_pressure_hpa is more
  # than this amount from the start_pressure_hpa, a warning will be
  # printed.
  max_prs_diff = 250.0*units('hPa')

  # # MDF: 11/11/24
  # pressure = pressure * units('hPa')
  # temperature = temperature * units('K')
    
  # Find the starting pressure in the profile
  if start_pressure_hpa < 0:
    start_prs = pressure[0]
    if db:
      print("")
      print("USING LOWEST STARTING PRESSURE: %f\n" % (start_prs.m))
  else:
    if interp:
      start_prs = log_interp_1d(start_pressure_hpa,pressure.m,pressure.m)
      start_prs = start_prs*units('hPa')
      # If the starting pressure is NaN, most likely the starting pressure was lower than
      # all the pressures in the sounding.
      if np.isnan(start_prs):
        if db:
          print("")
          print("WARNING. REQUESTED STARTING PRESSURE INVALID")
          print("UNABLE TO COMPUTE CTP.")
        return(-9999.*units('J/kg'))
      if db:
        print("")
        print("USING INTERPOLATED STARTING PRESSURE: %f\n" % (start_prs.m))
    else:
      # Find the closest value. We'll just take the difference between the start pressure and pressure
      # and find the index of the minimum
      prs_diff = pressure-(start_pressure_hpa*units('hPa'))
      start_prs = pressure[np.argmin(np.abs(prs_diff))]
      if np.abs(start_pressure_hpa-start_prs)>=max_prs_diff:
        print("")
        print("WARNING! ACTUAL STARTING PRESSURE IS AT LEAST %3.2f hPa FROM REQUESTED START PRESSURE." % (max_prs_diff.m))
        print("requested: start_pressure_hpa = %4.2f hPa" % (start_pressure_hpa.m))
        print("actual: start_pressure_hps = %4.2f hPa" % (start_prs.m))
      if db:
        print("")
        print("USING NEAREST STARTING PRESSURE: %f\n" % (start_prs.m))

  # Based on the starting pressure, set the initial layer bottom and top pressures
  layer_bot_prs = start_prs-(bot_pressure_hpa*units('hPa'))
  layer_top_prs = start_prs-(top_pressure_hpa*units('hPa'))

  if db:
    print("")
    print("TARGET LAYER BOTTOM PRESSURE: %f\n" % (layer_bot_prs.m))
    print("TARGET LAYER TOP PRESSURE: %f\n" % (layer_top_prs.m))

  # Obtain information at the top and bottom of the layer
  if interp:
    prsBot, tmpBot = log_interp_1d(layer_bot_prs.m,pressure.m,pressure.m,temperature.m)
    prsTop, tmpTop = log_interp_1d(layer_top_prs.m,pressure.m,pressure.m,temperature.m)
    if db:
      print("")
      print("USING INTERPOLATED LAYER BOTTOM PRESSURE: %f\n" % (prsBot))
      print("USING INTERPOLATED LAYER TOP PRESSURE: %f\n" % (prsTop))

    # Find the top and bottom of the layer, where the interpolated values should be inserted
    if any(np.where(np.diff(pressure.m)<=0)):
      if db:
        print("WARNING! PRESSURES DO NOT MONOTONICALLY DECREASE!")
        print("UNABLE TO COMPUTE CTP.")
      return(-9999.*units('J/kg'))
    layer_bot_idx = len(pressure.m)-np.searchsorted(pressure.m[::-1],prsBot,side="left")[0]
    layer_top_idx = len(pressure.m)-np.searchsorted(pressure.m[::-1],prsTop,side="left")[0]
    if db:
      print("")
      print("INSERTING INTERPOLATED BOT DATA AT INDEX: %02d" % (int(layer_bot_idx)))
      print("INSERTING INTERPOLATED TOP DATA AT INDEX: %02d" % (int(layer_top_idx)))

    # Create a new sounding to use, which has the interpolated T/P at bottom/top inserted
    prs = np.append(np.append(np.append(np.append(pressure.m[0:layer_bot_idx],prsBot),pressure.m[layer_bot_idx:layer_top_idx]),prsTop),pressure.m[layer_top_idx:])
    tmp = np.append(np.append(np.append(np.append(temperature.m[0:layer_bot_idx],tmpBot),temperature.m[layer_bot_idx:layer_top_idx]),tmpTop),temperature.m[layer_top_idx:])
    # Assign units to the new sounding variables
    prs = prs*units('hPa')
    tmp = tmp*units('degK')

    # Reset the variables as if this was the true sounding
    pressure = prs
    temperature = tmp

    # Find the new layer top and bottom indices, which should be the indices of the interpolated values that were inserted above
    layer_bot_idx = np.where(pressure.m==prsBot)[0][0]
    layer_top_idx = np.where(pressure.m==prsTop)[0][0]
    if db:
      print("")
      print("INDEX OF LAYER BOT: %02d" % (int(layer_bot_idx)))
      print("INDEX OF LAYER TOP: %02d" % (int(layer_top_idx)))

    # Compute the moist adiabatic lapse rate
    try:
      MALR = mpcalc.moist_lapse(pressure[layer_bot_idx:],tmpBot*units('degK'),reference_pressure=prsBot*units('hPa'))
    except ValueError:
      print("UNABLE TO COMPUTE MALR IN calc_ctp()")
      return(-9999.*units('J/kg'))

  else:

    # Find the index of the closest value. 
    # We'll just take the difference between the top/bottom pressure and find the index of the minimum
    bot_diff = pressure-layer_bot_prs
    top_diff = pressure-layer_top_prs
    layer_bot_idx = np.argmin(np.abs(bot_diff))
    layer_top_idx = np.argmin(np.abs(top_diff))
    if db:
      print("")
      print("INDEX OF LAYER BOT: %02d" % (int(layer_bot_idx)))
      print("INDEX OF LAYER TOP: %02d" % (int(layer_top_idx)))

    prsBot = pressure.m[layer_bot_idx]
    prsTop = pressure.m[layer_top_idx]
    tmpBot = temperature.m[layer_bot_idx]
    tmpTop = temperature.m[layer_top_idx]

    if db:
      print("")
      print("USING NEAREST LAYER BOTTOM PRESSURE: %f\n" % (prsBot))
      print("USING NEAREST LAYER TOP PRESSURE: %f\n" % (prsTop))

    # Compute the moist adiabatic lapse rate
    try:
      MALR = mpcalc.moist_lapse(pressure[layer_bot_idx:],tmpBot*units('degK'),reference_pressure=prsBot*units('hPa'))
    except ValueError:
      print("UNABLE TO COMPUTE MALR IN calc_ctp()")
      return(-9999.*units('J/kg'))

  # The MALR was only computed from the pressure at the bottom of the layer to the top of the sounding,
  # so subset the data to align with the levels where the MALR was computed
  ctp_prs = pressure[layer_bot_idx:]
  ctp_tmp = temperature[layer_bot_idx:]

  # Compute the difference between the environmental temperature profile and the MALR
  tdiff = (ctp_tmp-MALR)

  # Create a mask for the layer we want to integrate over
  p_mask = (ctp_prs<=pressure[layer_bot_idx])&(ctp_prs>=pressure[layer_top_idx])

  # Compute the Convective Triggering Potential (CTP) index
  CTP = mpconsts.Rd * units.Quantity(np.trapz(tdiff[p_mask].m,np.log(ctp_prs[p_mask].m)),'K')

  if plotskewt:
    import matplotlib.pyplot as plt
    from metpy.plots import SkewT
    fig = plt.figure(1, figsize=(22,15))
    skew = SkewT(fig=fig,rotation=45.0)
    skew.plot(pressure,temperature,'r',marker='.',linewidth=4)
    skew.ax.axhline(y=pressure[layer_bot_idx],xmin=-80,xmax=80,color='k',linewidth=2,linestyle='--')
    skew.ax.axhline(y=pressure[layer_top_idx],xmin=-80,xmax=80,color='k',linewidth=2,linestyle='--')
    skew.ax.fill_betweenx(pressure[layer_bot_idx:layer_top_idx+1],temperature[layer_bot_idx:layer_top_idx+1],MALR[0:(layer_top_idx-layer_bot_idx)+1])
    skew.plot(pressure[layer_bot_idx:],MALR,marker='.',linewidth=4,color='magenta')
    skew.ax.set_ylabel('Pressure (hPa)')
    skew.ax.set_xlabel('Temperature (C)')
    plt.title('CTP = %5.5f J/kg' % (float(CTP.m)),loc='left')
    plt.title('STATION = %s' % (station))
    fig.savefig(os.path.join(plotdir,'CTP_%s.png' % (station)))
    plt.close()

  return CTP.magnitude

# %% [markdown]
# ### DASK

# %%
import dask
dask.config.set({'logging.distributed': 'error'})

from dask_jobqueue import PBSCluster

# For Casper
cluster = PBSCluster(
    queue="casper",
    walltime="03:00:00",
    account="P93300042",
    memory="4GB",
    resource_spec="select=1:ncpus=2:mem=4GB",
    cores=1,
    processes=1,
)

from dask.distributed import Client

# Connect client to the remote dask workers
client = Client(cluster)
print(client)

cluster.scale(8)

client.wait_for_workers(8)
# Out:
# /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44369 instead
#   warnings.warn(
# <Client: 'tcp://128.117.208.103:44999' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Read in one piece of CESM data to get grid

# %%
caseNames = [
            'f.e21.F2000climo.f09_f09_mg17.S2S_LandAtmCoupling_output.002',
            'f.e21.F2000climo.f09_f09_mg17.ReduceDSL_0p8to0p5.S2S_LandAtmCoupling_output.002',
            # 'i.e21.I2000Clm50Sp.f09_f09_mg17.S2S_LandAtmCoupling_output.002',
            # 'f.e21.FHIST.f09_f09_mg17.S2S_LandAtmCoupling_output.002',
           ]

case_IDs = [
            'F2000climo_ctrl',
            'F2000climo_dsl0p5',
            # 'I2000Clm50Sp',
            # 'FHIST_ctrl', 
            ]

dataDir = '/glade/campaign/cgd/tss/people/mdfowler/LandAtmCoupling_longRuns/'

iCase=0

## Select files with daily means (h1 files in this case)
listFiles_atm_lev = np.sort(glob.glob(dataDir+caseNames[iCase]+'/atm/hist/*cam.h3.????-*'))

DS_cam = xr.open_dataset(listFiles_atm_lev[0])

# %%
## Get landfrac
h0_files = np.sort(glob.glob(dataDir+caseNames[iCase]+'/atm/hist/*cam.h0.????-*'))
landfrac = xr.open_dataset(h0_files[1]).LANDFRAC
landfrac = landfrac.isel(time=0).sel(lat=slice(15,55), lon=slice(225,300))

# %%
landMask = np.ones([len(landfrac.lat.values), len(landfrac.lon.values)])
landMask[np.squeeze(landfrac.values)<=0.45] = np.nan

# %% [markdown]
# ## Get RDA ERA5 data instead

# %%
def preprocess_era5(DS):
    ## Select only hours 12-15 UTC
    # iHours = np.where( (DS['time.hour']>=12) & (DS['time.hour']<=14))[0]
    ## Select only hours 9-11 UTC
    iHours = np.where( (DS['time.hour']>=9) & (DS['time.hour']<=11))[0]
    iLevs  = np.where(DS.level.values>=500)[0]
    DS_sel = DS.isel(time=iHours, level=iLevs).resample(time='1D').mean()

    
    ## Regrid
    DS_sel  = DS_sel.rename({'longitude': 'lon','latitude': 'lat'})
    camGrid = DS_cam['PS'].isel(time=0).load().squeeze()
    regridERA = regrid_data(DS_sel, camGrid, method=1)
        
    DS_sel2 = regridERA.sel(lat=slice(15,55), lon=slice(225, 300))

        
    return DS_sel2.load()

# %%
dataDir = '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/'

years = 1995+np.arange(11)
print(years)

months = ['06','07','08']

count = 0 
for iYr in range(len(years)):
    for iMon in range(len(months)):
        listFiles_q_temp = np.sort(glob.glob(dataDir+str(years[iYr])+months[iMon]+'/*_q*.nc'))
        listFiles_t_temp = np.sort(glob.glob(dataDir+str(years[iYr])+months[iMon]+'/*_t*.nc'))

        if count==0:
            listFiles_q = listFiles_q_temp
            listFiles_t = listFiles_t_temp
        else: 
            listFiles_q = np.append(listFiles_q, listFiles_q_temp)
            listFiles_t = np.append(listFiles_t, listFiles_t_temp)

        count = count+1
# Out:
# [1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005]

# %%
# %%time
q_era5 = xr.open_mfdataset(np.sort(listFiles_q), preprocess=preprocess_era5, 
                           # combine='by_coords',
                           combine='nested', concat_dim='time', 
                           decode_times=True, data_vars='minimal', parallel=True, 
                           # chunks={'time': 150},
                          )
# Out:
# CPU times: user 1min 7s, sys: 4.81 s, total: 1min 12s
# Wall time: 14min 9s

# %%
# %%time
t_era5 = xr.open_mfdataset(np.sort(listFiles_t), preprocess=preprocess_era5, 
                                # combine='by_coords',
                               concat_dim='time', combine='nested', 
                                 decode_times=True, data_vars='minimal', parallel=True,
                                 # chunks={'time': 150},
                          )
# Out:
# CPU times: user 1min 28s, sys: 5.1 s, total: 1min 33s
# Wall time: 16min 23s

# %%
T_invertLev = t_era5.isel(level=slice(None, None, -1))
Q_invertLev = q_era5.isel(level=slice(None, None, -1))

# %%
T_invertLev.T.isel(time=10, level=0).plot()
plt.plot(263,32,'ko')

# %%
T_point = T_invertLev.sel(lon=263, lat=32, method='nearest')
Q_point = Q_invertLev.sel(lon=263, lat=32, method='nearest')

# %%
plt.hist(T_point.isel(level=1).T.values, bins=np.arange(260,320,5))
plt.title('ERA5 Temperature Histogram\n'+'Lon: '+str(T_point.lon.values)+' / Lat: '+str(T_point.lat.values) + ' / Lev = '+str(T_point.isel(level=1).level.values))
plt.xlabel('Temperature (K)')
plt.ylabel('Bin Count')
# Out:
# Text(0, 0.5, 'Bin Count')

# %%
plt.hist(Q_point.isel(level=1).Q.values, bins=np.arange(-0.01,0.1, 0.005))
plt.title('ERA5 Sp. Hum. Histogram\n'+'Lon: '+str(T_point.lon.values)+' / Lat: '+str(T_point.lat.values) + ' / Lev = '+str(T_point.isel(level=1).level.values))
plt.xlabel('Specific Humidity (kg kg**-1)')
plt.ylabel('Bin Count')
# Out:
# Text(0, 0.5, 'Bin Count')

# %%
dewpoint = mpc.dewpoint_from_specific_humidity(Q_point.isel(level=0).level.values * units.hPa, 
                                               Q_point.isel(level=0).Q.values * units('kg/kg') )
print(dewpoint)
# Out:
# [18.181008975490386 21.56679067724906 21.373193616971548 ... 20.975700082998628 18.547678632177906 18.462394941286448] degree_Celsius

# %%
nTime,nLev,nLat,nLon = np.shape(T_invertLev.T)

# %%
output=np.full([nTime,nLat,nLon], np.nan)

for iLat in tqdm(range(nLat)):
    for iLon in range(nLon):
        if np.isfinite(landMask[iLat,iLon]):
            for iT in range(nTime):
                output[iT,iLat,iLon] = calc_ctp(T_invertLev.level.values * units.hPa,
                            T_invertLev.T.isel(time=iT,lat=iLat,lon=iLon).values * units.K,
                            start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
                            interp=False,db=False,plotskewt=False,plotdir="",station="")
# Out:
# 100%|██████████| 42/42 [1:19:09<00:00, 113.08s/it]

# %%
ctp = xr.DataArray(output, 
    coords={
            'time': T_invertLev.time.values,
            'lat':  T_invertLev.lat.values, 
            'lon':  T_invertLev.lon.values}, 
    dims=["time", "lat", "lon"])

# %%
ctp.isel(time=6).plot()

# %%
# outdir = '/glade/derecho/scratch/mdfowler/S2S_processed/'
# # fileName = outdir+'ERA5_CTP_JJA_13utc.nc'
# fileName = outdir+'ERA5_CTP_JJA_10utc.nc'

# # ctp.to_netcdf(path=fileName)

# %%
outdir = '/glade/derecho/scratch/mdfowler/S2S_processed/'

ctp_10utc = xr.open_dataset(outdir+'ERA5_CTP_JJA_10utc.nc')
ctp_13utc = xr.open_dataset(outdir+'ERA5_CTP_JJA_13utc.nc')

## Around longitude = 110, switch from 13 UTC to 10 UTC. Could also try 105, which is ~longitude of Denver (going with Denver) 
iLon = np.where( (T_invertLev.lon.values>=254) & (T_invertLev.lon.values<=256))[0] 

ctp_combined = ctp_13utc.__xarray_dataarray_variable__.values
ctp_combined[:,:,iLon[0]::] = ctp_10utc.__xarray_dataarray_variable__.values[:,:,iLon[0]::]

ctp = xr.DataArray(ctp_combined, 
    coords={
            'time': T_invertLev.time.values,
            'lat':  T_invertLev.lat.values, 
            'lon':  T_invertLev.lon.values}, 
    dims=["time", "lat", "lon"])

# %%
ctp_noZeros = ctp.where(ctp.values>=0)

# %%
#   Set up to add states to plots
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')


fig, axs = plt.subplots(1,1, figsize=(12, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
# axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

p1 = axs.contourf(ctp_noZeros.lon.values, ctp_noZeros.lat.values, 
            ctp_noZeros.median(dim='time').values,transform=ccrs.PlateCarree() )
fig.colorbar(p1)
axs.set_title('ERA5: Median of positive CTP days')
# Out:
# Text(0.5, 1.0, 'ERA5: Median of positive CTP days')

# %%
#   Set up to add states to plots
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')


fig, axs = plt.subplots(1,1, figsize=(12, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
# axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

p1 = axs.contourf(ctp.lon.values, ctp.lat.values, 
            ctp.median(dim='time').values,transform=ccrs.PlateCarree() )
fig.colorbar(p1)
axs.set_title('Median of CTP on *all* days')
# Out:
# Text(0.5, 1.0, 'Median of CTP on *all* days')

# %% [markdown]
# ## Compute HiLow

# %%
dewpoint_950 = mpc.dewpoint_from_specific_humidity(Q_invertLev.sel(level=950, method='nearest').level.values * units.hPa, 
                                                   Q_invertLev.Q.sel(level=950, method='nearest').values * units('kg/kg'))

dewpoint_850 = mpc.dewpoint_from_specific_humidity(Q_invertLev.sel(level=850, method='nearest').level.values * units.hPa, 
                                                   Q_invertLev.Q.sel(level=850, method='nearest').values * units('kg/kg'))

# %%
# tmpBot =  T_invertLev.sel(lev=950, method='nearest').values * units(DS_case0.T.units) -273.15
# tmpTop =  T_invertLev.sel(lev=850, method='nearest').values * units(DS_case0.T.units) -273.15
tmpBot =  T_invertLev.T.sel(level=950, method='nearest').values -273.15
tmpTop =  T_invertLev.T.sel(level=850, method='nearest').values -273.15

HIlow = (tmpBot-dewpoint_950.m) + (tmpTop-dewpoint_850.m)

# %%
HIlow
# Out:
# array([[[ 9.42562285, 12.77554665, 13.01141846, ...,  6.2772601 ,
#           6.44288033,  6.16596916],
#         [17.67251414,  8.97608775, 12.72443477, ...,  6.06587424,
#           6.40807804,  5.57448984],
#           8.75231171, 13.08456196],
#         [ 5.93121323,  5.04998219,  5.81834373, ...,  7.87375279,
#           5.80808329, 11.5959481 ],
#         [12.088785  , 10.54357669, 20.28866506, ...,  6.62622997,
#           7.16554246, 10.51341624],
#         ...,
#         [ 6.17557119,  6.00619371,  4.58477207, ...,  1.02421357,
#           1.47087431,  2.5814024 ],
#         [ 5.27282754,  5.06952502,  3.28584083, ...,  2.80024815,
#           2.39859084,  2.28547355],
#         [ 6.06814959,  4.76604548,  5.31314324, ...,  3.13718177,
#           3.82005378,  5.66473877]]])

# %%
HI_low = xr.DataArray(HIlow, 
    coords={
            'time': T_invertLev.time.values,
            'lat':  T_invertLev.lat.values, 
            'lon':  T_invertLev.lon.values}, 
    dims=["time", "lat", "lon"])

# %% [markdown]
# ## Compute bins

# %%
DS_main = HI_low.to_dataset(name="HIlow")
DS_main["CTP"] = ctp

# %%
category = np.full([len(DS_main.lat.values), len(DS_main.lon.values)], 'NotClassifiedYet')


for iLat in range(len(DS_main.lat.values)):
    for iLon in range(len(DS_main.lon.values)): 
        thisPoint = DS_main.isel(lat=iLat,lon=iLon)
        nDays     = len(thisPoint.time.values)

        # Confirm we have CTP values (over land)
        if np.all(np.isfinite(thisPoint.CTP.values)==True):
            iAtmControl = np.where((thisPoint.CTP.values<=0) | (thisPoint.HIlow.values<=5) | (thisPoint.HIlow.values>=15) )[0]
            iWetRegime  = np.where((thisPoint.CTP.values>0) & (thisPoint.HIlow.values>5) &  (thisPoint.HIlow.values<10))[0]
            iDryRegime  = np.where((thisPoint.CTP.values>0) & (thisPoint.HIlow.values>=10) &  (thisPoint.HIlow.values<15))[0]

            nDays_atm = len(iAtmControl)
            nDays_other = nDays-nDays_atm

            if len(iAtmControl)>=np.floor(nDays*0.8):
                category[iLat,iLon]='AtmControl'
            elif len(iWetRegime)>=np.floor(nDays_other*0.5):
                category[iLat,iLon]='Positive_wet'
            elif len(iDryRegime)>=np.floor(nDays_other*0.5):
                category[iLat,iLon]='Negative_dry'

# %%
coded_array = np.full([len(DS_main.lat.values), len(DS_main.lon.values)], np.nan)
coded_array[np.where(category=='AtmControl')]   = 1
coded_array[np.where(category=='Positive_wet')] = 2
coded_array[np.where(category=='Negative_dry')] = 3

# %%
fig, axs = plt.subplots(1,1, figsize=(12, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
# axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

p1 = axs.pcolormesh(ctp.lon.values, ctp.lat.values, 
            coded_array,transform=ccrs.PlateCarree(), cmap='brg' )
c1 = fig.colorbar(p1)
axs.set_title('ERA5: CTP-HIlow classification')

# axs.plot((360-96.56), 39.08, 'k*', transform=ccrs.PlateCarree())
# Out:
# Text(0.5, 1.0, 'ERA5: CTP-HIlow classification')

# %% [markdown]
# # Old code

# %% [markdown]
# ## Run some tests & Compute

# %%
## Sanity test? What about RDA ERA5...


dataDir = '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/1995??/'


listFiles_q = np.sort(glob.glob(dataDir+'*_q*.nc'))

listFiles_q
# Out:
# array(['/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995010100_1995010123.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995010200_1995010223.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995010300_1995010323.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995010400_1995010423.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995010500_1995010523.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995010600_1995010623.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199501/e5.oper.an.pl.128_133_q.ll025sc.1995
.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121200_1995121223.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121300_1995121323.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121400_1995121423.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121500_1995121523.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121600_1995121623.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121700_1995121723.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121800_1995121823.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995121900_1995121923.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122000_1995122023.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122100_1995122123.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122200_1995122223.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122300_1995122323.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122400_1995122423.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122500_1995122523.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122600_1995122623.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122700_1995122723.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122800_1995122823.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995122900_1995122923.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995123000_1995123023.nc',
#        '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199512/e5.oper.an.pl.128_133_q.ll025sc.1995123100_1995123123.nc'],
#       dtype='<U122')

# %%
## Sanity test? What about RDA ERA5...
dataDir = '/glade/campaign/collections/rda/data/d633000/e5.oper.an.pl/199506/'


listFiles_q = np.sort(glob.glob(dataDir+'*_q*.nc'))
q_sanity = xr.open_mfdataset(listFiles_q, concat_dim='time', combine='nested')

# %%
q_sanity.sel(longitude=-110, latitude=34, method='nearest').isel(level=-2).Q.plot()
Q_era5.sel(longitude=250, latitude=34, method='nearest').isel(pressure_level=0, valid_time=np.arange(30)).q.plot()

# %%
Q_era5.valid_time.values
# Out:
# array(['1995-06-01T09:00:00.000000000', '1995-06-01T10:00:00.000000000',
#        '1995-06-01T11:00:00.000000000', ...,
#        '2005-08-31T12:00:00.000000000', '2005-08-31T13:00:00.000000000',
#        '2005-08-31T14:00:00.000000000'], dtype='datetime64[ns]')

# %%
T_point = T_era5.sel(longitude=280, latitude=34, method='nearest')
Q_point = Q_era5.sel(longitude=280, latitude=34, method='nearest')

# %%
Q_point.dropna(dim='valid_time')
# Out:
# <xarray.Dataset>
# Dimensions:         (valid_time: 1012, pressure_level: 8)
# Coordinates:
#     number          int64 0
#   * pressure_level  (pressure_level) float64 975.0 950.0 925.0 ... 750.0 700.0
#     latitude        float64 40.0
#     longitude       float64 256.0
#   * valid_time      (valid_time) datetime64[ns] 1995-06-01 ... 2005-08-31
# Data variables:
#     q               (valid_time, pressure_level) float32 0.007096 ... 0.00207
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-11-21T23:38 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
plt.hist(T_point.isel(pressure_level=0).t.values, bins=np.arange(260,320,5))
plt.title('ERA5 Temperature Histogram\n'+'Lon: '+str(T_point.longitude.values)+' / Lat: '+str(T_point.latitude.values) + ' / Lev = '+str(T_point.isel(pressure_level=0).pressure_level.values))
plt.xlabel('Temperature (K)')
plt.ylabel('Bin Count')

# %%
plt.hist(Q_point.isel(pressure_level=0).q.values, bins=np.arange(-0.01,0.1, 0.005))
plt.title('ERA5 Sp. Hum. Histogram\n'+'Lon: '+str(T_point.longitude.values)+' / Lat: '+str(T_point.latitude.values) + ' / Lev = '+str(T_point.isel(pressure_level=0).pressure_level.values))
plt.xlabel('Specific Humidity (kg kg**-1)')
plt.ylabel('Bin Count')

# %%
dewpoint = mpc.dewpoint_from_specific_humidity(Q_point.isel(pressure_level=0).pressure_level.values * units.hPa, 
                                               Q_point.isel(pressure_level=0).q.values * units('kg/kg') )

# %%
dewpoint
# Out:
# array([  3.1541748,   3.4184875,   3.6094055, ..., -10.29657  ,
#        -10.222443 ,  -9.861572 ], dtype=float32) <Unit('degree_Celsius')>

# %%
testPoint = np.full([nTime],np.nan)
for iT in range(nTime):
    testPoint[iT] = calc_ctp(T_point.pressure_level.values * units.hPa,
                T_point.isel(valid_time=iT).t.values * units.K,
                start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
                interp=False,db=False,plotskewt=False,plotdir="",station="")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 testPoint = np.full([nTime],np.nan)
#       2 for iT in range(nTime):
# ----> 3     testPoint[iT] = calc_ctp(T_point.pressure_level.values * units.hPa,
#       4                 T_point.isel(valid_time=iT).t.values * units.K,
#       5                 start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
#       6                 interp=False,db=False,plotskewt=False,plotdir="",station="")
#
# Cell In[3], line 168, in calc_ctp(pressure, temperature, start_pressure_hpa, bot_pressure_hpa, top_pressure_hpa, interp, db, plotskewt, plotdir, station)
#     165 p_mask = (ctp_prs<=pressure[layer_bot_idx])&(ctp_prs>=pressure[layer_top_idx])
#     167 # Compute the Convective Triggering Potential (CTP) index
# --> 168 CTP = mpconsts.Rd * units.Quantity(np.trapz(tdiff[p_mask].m,np.log(ctp_prs[p_mask].m)),'K')
#     170 if plotskewt:
#     171   import matplotlib.pyplot as plt
#
# File /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/pint/facets/numpy/quantity.py:253, in NumpyQuantity.__getitem__(self, key)
#     251 def __getitem__(self, key):
#     252     try:
# --> 253         return type(self)(self._magnitude[key], self._units)
#     254     except PintTypeError:
#     255         raise
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 1 but corresponding boolean dimension is 5

# %%
plt.plot(testPoint)
plt.axhline(np.median(testPoint),color='y')
plt.xlim([0,100])
# iT = 35
# plt.plot(iT,testPoint[iT],'ko')

# %%
# output=np.full([nTime,nLat,nLon], np.nan)

# for iLat in tqdm(range(nLat)):
#     for iLon in range(nLon):
#         if np.isfinite(landMask[iLat,iLon]):
#             for iT in range(nTime):
#                 output[iT,iLat,iLon] = calc_ctp(T_invertLev.lev.values * units.hPa,
#                             T_invertLev.isel(time=iT,lat=iLat,lon=iLon).values * units.K,
#                             start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
#                             interp=False,db=False,plotskewt=False,plotdir="",station="")

# %% [markdown]
# ## Get data

# %%
def preprocess_atm_profiles(ds):
    ds         = cesm_correct_time(ds)
    dsSel      = ds[['T','Q','PS','hyam','hyai','hybm','hybi','P0']]

    # - - - - Isolate only JJA, for years 2 onwards, and only the early morning time each day
    # Drop first year and only keep JJA 
    # iTimes = np.where( (dsSel['time.year'].values>=(dsSel['time.year'].values[0]+1))  & 
    #                    (dsSel['time.month'].values>=6) & (dsSel['time.month'].values<=8) 
    #                   & (dsSel['time.hour'].values==10) )[0]
    iTimes = np.where( (dsSel['time.hour'].values<=13) & (dsSel['time.hour'].values>=10))[0]
    dsSel = dsSel.isel(time=iTimes)
    
    # Also select spatial range (CONUS)
    dsSel = dsSel.sel(lat=slice(10,50), lon=slice(190,310), lev=slice(500,1000))


    return dsSel

# %%
caseNames = [
            'f.e21.F2000climo.f09_f09_mg17.S2S_LandAtmCoupling_output.002',
            'f.e21.F2000climo.f09_f09_mg17.ReduceDSL_0p8to0p5.S2S_LandAtmCoupling_output.002',
            # 'i.e21.I2000Clm50Sp.f09_f09_mg17.S2S_LandAtmCoupling_output.002',
            # 'f.e21.FHIST.f09_f09_mg17.S2S_LandAtmCoupling_output.002',
           ]

case_IDs = [
            'F2000climo_ctrl',
            'F2000climo_dsl0p5',
            # 'I2000Clm50Sp',
            # 'FHIST_ctrl', 
            ]

dataDir = '/glade/campaign/cgd/tss/people/mdfowler/LandAtmCoupling_longRuns/'

# %%
# %%time 

# iCase=0

# # for iCase in range(len(case_IDs)):
# print('*** Starting on case %s ***' % (case_IDs[iCase]))

# ## Select files with daily means (h1 files in this case)
# listFiles_atm_lev = np.sort(glob.glob(dataDir+caseNames[iCase]+'/atm/hist/*cam.h3.????-*'))


# DS_case0 = xr.open_mfdataset(listFiles_atm_lev,  preprocess=preprocess_atm_profiles, concat_dim='time', 
#                             combine='nested', decode_times=False, 
#                             data_vars='minimal', parallel=True)

# print('atm 3D files loaded')
# Out:
# *** Starting on case F2000climo_ctrl ***
# atm 3D files loaded
# CPU times: user 33.5 s, sys: 2.29 s, total: 35.8 s
# Wall time: 2min 29s

# %%
# ## Get landfrac
# h0_files = np.sort(glob.glob(dataDir+caseNames[iCase]+'/atm/hist/*cam.h0.????-*'))
# landfrac = xr.open_dataset(h0_files[1]).LANDFRAC
# landfrac = landfrac.isel(time=0).sel(lat=slice(10,50), lon=slice(190,310))

# %%
# landMask = np.ones([len(landfrac.lat.values), len(landfrac.lon.values)])
# landMask[np.squeeze(landfrac.values)<=0.45] = np.nan

# %%
# # Drop first year and only keep JJA 
# iTimes = np.where( (DS_case0['time.year'].values>=(DS_case0['time.year'].values[0]+1))  & 
#                    (DS_case0['time.month'].values>=6) & (DS_case0['time.month'].values<=8) 
#                   )[0]

# DS_case0 = DS_case0.isel(time=iTimes)

# %%
# selHr = 13

# iHours = np.where( (DS_case0['time.hour'].values==13) )[0]
# len(iHours)

# DS_case0 = DS_case0.isel(time=iHours)

# %%
#from joblib import Parallel, delayed, parallel_config

# %%
# P_interp = np.append(np.arange(550, 900, 50), np.arange(900,1000, 25))
# P_interp = np.append(P_interp, 990)

# T_interp_temp = interpolateToPressure(DS_case0, 'T', P_interp)

# T_interp = xr.DataArray(T_interp_temp, 
#     coords={
#             'time': DS_case0.time.values,
#             'lev':  P_interp,
#             'lat':  DS_case0.lat.values, 
#             'lon':  DS_case0.lon.values}, 
#     dims=["time", "lev", "lat", "lon"])

# T_invertLev = T_interp.isel(lev=slice(None, None, -1))

# %%
# P_interp = np.append(np.arange(550, 900, 50), np.arange(900,1000, 25))
# P_interp = np.append(P_interp, 990)

# Q_interp_temp = interpolateToPressure(DS_case0, 'Q', P_interp)

# Q_interp = xr.DataArray(Q_interp_temp, 
#     coords={
#             'time': DS_case0.time.values,
#             'lev':  P_interp,
#             'lat':  DS_case0.lat.values, 
#             'lon':  DS_case0.lon.values}, 
#     dims=["time", "lev", "lat", "lon"])

# Q_invertLev = Q_interp.isel(lev=slice(None, None, -1))

# %%
print(DS_case0.Q.units)
# Out:
# kg/kg

# %%
nTime,nLev,nLat,nLon = np.shape(T_invertLev)

# %%
from tqdm import tqdm

# %%
T_invertLev_point = T_invertLev.sel(lon=250, lat=38, method='nearest')
Q_invertLev_point = Q_invertLev.sel(lon=250, lat=38, method='nearest')

# %%
dewpoint = mpc.dewpoint_from_specific_humidity(Q_invertLev_point.isel(lev=0).lev.values * units.hPa, 
                                               Q_invertLev_point.isel(lev=0).values * units('kg/kg') )

# %%
dewpoint
# Out:
# array([27.45101711, 21.97955813, 22.18908542, ..., 29.9453037 ,
#        24.66923164, 20.17422851]) <Unit('degree_Celsius')>

# %%
testPoint = np.full([nTime],np.nan)
for iT in range(nTime):
    testPoint[iT] = calc_ctp(T_invertLev_point.lev.values * units.hPa,
                T_invertLev_point.isel(time=iT).values * units.K,
                start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
                interp=False,db=False,plotskewt=False,plotdir="",station="")

# %%
plt.plot(testPoint)
plt.axhline(np.median(testPoint),color='y')
plt.xlim([0,100])
iT = 35
plt.plot(iT,testPoint[iT],'ko')

T_invertLev_point_time = T_invertLev_point.isel(time=iT)

# %%
calc_ctp(T_invertLev_point_time.lev.values * units.hPa,
                T_invertLev_point_time.values * units.K,
                start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
                interp=False,db=True,plotskewt=False,plotdir="",station="")
# Out:
# USING LOWEST STARTING PRESSURE: 990.000000
#
#
# TARGET LAYER BOTTOM PRESSURE: 890.000000
#
# TARGET LAYER TOP PRESSURE: 690.000000
#
#
# INDEX OF LAYER BOT: 04
# INDEX OF LAYER TOP: 08
#
# USING NEAREST LAYER BOTTOM PRESSURE: 900.000000
#
# USING NEAREST LAYER TOP PRESSURE: 700.000000
# 451.0608590785801

# %%
pressure    = T_invertLev_point_time.sel(lev=slice(900,700)).lev.values * units.hPa
temperature = T_invertLev_point.isel(time=iT).sel(lev=slice(900,700)).values * units.K
moisture    = Q_invertLev_point.isel(time=iT).sel(lev=slice(900,700)).values *1e3 * units('g/kg')

dewpoint_time   = dewpoint.m[iT] * dewpoint.u
temperature_sfc = T_invertLev_point.isel(time=iT, lev=0).values * units.K

# %%
print(pressure)
print(temperature)
print(moisture * 1e3 * units('g/kg'))
# Out:
# [900 850 800 750 700] hectopascal
# [308.93170587285846 303.49615007638056 298.53727246979383 296.2320041201997 290.9509822810801] kelvin
# [13.56641121060293 10.242354840748153 6.866398179431457 5.314958056508732 5.402689836589365] gram / kilogram

# %%
dewp = np.full([len(pressure.m)], np.nan)
for iLev in range(len(pressure.m)):
    dewp[iLev] = mpc.dewpoint_from_specific_humidity(pressure.m[iLev] * pressure.u, moisture.m[iLev] * moisture.u ).m

# %%
parcProf = mpc.parcel_profile(pressure, 
                              temperature_sfc, dewpoint_time)

# %%
cape,cin = mpc.cape_cin(pressure, temperature, dewp * dewpoint.u, 
                        parcProf, which_lfc='bottom', which_el='top')

print(cape)
print(cin)
# Out:
# 0 joule / kilogram
# 0 joule / kilogram

# %%
# def calc_ctp(pressure,temperature,start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,interp=False,db=False,plotskewt=False,plotdir="",station=""):

  """ Function for computing the Convective Triggering Potential
  Args:
      pressure (pint.Quantity): the vertical pressure profile
      temperature (pint.Quantity): the vertical temperature profile
      start_pressure_hpa (float, optional): the starting pressure to use. Default: -1 (bottom level in profile).
      bot_pressure_hpa (float, optional): bottom pressure value of the layer, added to start_pressure_hpa. Default: 100 hPa.
      top_pressure_hpa (float, optional): top pressure value of the layer, added to start_pressure_hpa. Default: 300 hPa.
      interp (bool): Whether to interpolate data to exact pressures or use the closest. Default: False.
      db (bool): Print debugging statements. Default: False
      plotskewt (bool): Plot a Skew-T Log-P graphic of the CTP calculation. Default: False.
      plotdir (string, optional): Directory where Skew-T plots should be written. Default: "".
      station (string, optional): Location ID string used for labeling the Skew-T plot and image file name. Default: "".
  Returns:
      float32
 
  Reference:
      TBD
  Notes:
      Lorem Ipsum
  """

    max_prs_diff = 250.0*units('hPa')

  # # MDF: 11/11/24
  # pressure = pressure * units('hPa')
  # temperature = temperature * units('K')
    
  # Find the starting pressure in the profile
  if start_pressure_hpa < 0:
    start_prs = pressure[0]
    if db:
      print("")
      print("USING LOWEST STARTING PRESSURE: %f\n" % (start_prs.m))
 
  # Based on the starting pressure, set the initial layer bottom and top pressures
  layer_bot_prs = start_prs-(bot_pressure_hpa*units('hPa'))
  layer_top_prs = start_prs-(top_pressure_hpa*units('hPa'))

  if db:
    print("")
    print("TARGET LAYER BOTTOM PRESSURE: %f\n" % (layer_bot_prs.m))
    print("TARGET LAYER TOP PRESSURE: %f\n" % (layer_top_prs.m))

  # Obtain information at the top and bottom of the layer
  if interp:
    prsBot, tmpBot = log_interp_1d(layer_bot_prs.m,pressure.m,pressure.m,temperature.m)
    prsTop, tmpTop = log_interp_1d(layer_top_prs.m,pressure.m,pressure.m,temperature.m)
    if db:
      print("")
      print("USING INTERPOLATED LAYER BOTTOM PRESSURE: %f\n" % (prsBot))
      print("USING INTERPOLATED LAYER TOP PRESSURE: %f\n" % (prsTop))

    # Find the top and bottom of the layer, where the interpolated values should be inserted
    if any(np.where(np.diff(pressure.m)<=0)):
      if db:
        print("WARNING! PRESSURES DO NOT MONOTONICALLY DECREASE!")
        print("UNABLE TO COMPUTE CTP.")
      return(-9999.*units('J/kg'))
    layer_bot_idx = len(pressure.m)-np.searchsorted(pressure.m[::-1],prsBot,side="left")[0]
    layer_top_idx = len(pressure.m)-np.searchsorted(pressure.m[::-1],prsTop,side="left")[0]
    if db:
      print("")
      print("INSERTING INTERPOLATED BOT DATA AT INDEX: %02d" % (int(layer_bot_idx)))
      print("INSERTING INTERPOLATED TOP DATA AT INDEX: %02d" % (int(layer_top_idx)))

    # Create a new sounding to use, which has the interpolated T/P at bottom/top inserted
    prs = np.append(np.append(np.append(np.append(pressure.m[0:layer_bot_idx],prsBot),pressure.m[layer_bot_idx:layer_top_idx]),prsTop),pressure.m[layer_top_idx:])
    tmp = np.append(np.append(np.append(np.append(temperature.m[0:layer_bot_idx],tmpBot),temperature.m[layer_bot_idx:layer_top_idx]),tmpTop),temperature.m[layer_top_idx:])
    # Assign units to the new sounding variables
    prs = prs*units('hPa')
    tmp = tmp*units('degK')

    # Reset the variables as if this was the true sounding
    pressure = prs
    temperature = tmp

    # Find the new layer top and bottom indices, which should be the indices of the interpolated values that were inserted above
    layer_bot_idx = np.where(pressure.m==prsBot)[0][0]
    layer_top_idx = np.where(pressure.m==prsTop)[0][0]
    if db:
      print("")
      print("INDEX OF LAYER BOT: %02d" % (int(layer_bot_idx)))
      print("INDEX OF LAYER TOP: %02d" % (int(layer_top_idx)))

    # Compute the moist adiabatic lapse rate
    try:
      MALR = mpcalc.moist_lapse(pressure[layer_bot_idx:],tmpBot*units('degK'),reference_pressure=prsBot*units('hPa'))
    except ValueError:
      print("UNABLE TO COMPUTE MALR IN calc_ctp()")
      return(-9999.*units('J/kg'))

  else:

    # Find the index of the closest value. 
    # We'll just take the difference between the top/bottom pressure and find the index of the minimum
    bot_diff = pressure-layer_bot_prs
    top_diff = pressure-layer_top_prs
    layer_bot_idx = np.argmin(np.abs(bot_diff))
    layer_top_idx = np.argmin(np.abs(top_diff))
    if db:
      print("")
      print("INDEX OF LAYER BOT: %02d" % (int(layer_bot_idx)))
      print("INDEX OF LAYER TOP: %02d" % (int(layer_top_idx)))

    prsBot = pressure.m[layer_bot_idx]
    prsTop = pressure.m[layer_top_idx]
    tmpBot = temperature.m[layer_bot_idx]
    tmpTop = temperature.m[layer_top_idx]
    if db: 
        print("")
        print("prsBot = ", prsBot)
        print("prsTop = ", prsTop)
        print("tmpBot = ", tmpBot)
        print("tmpTop = ", tmpTop)

    if db:
      print("")
      print("USING NEAREST LAYER BOTTOM PRESSURE: %f\n" % (prsBot))
      print("USING NEAREST LAYER TOP PRESSURE: %f\n" % (prsTop))

    # Compute the moist adiabatic lapse rate
    try:
      MALR = mpcalc.moist_lapse(pressure[layer_bot_idx:],tmpBot*units('degK'),reference_pressure=prsBot*units('hPa'))
    except ValueError:
      print("UNABLE TO COMPUTE MALR IN calc_ctp()")
      return(-9999.*units('J/kg'))

  # The MALR was only computed from the pressure at the bottom of the layer to the top of the sounding,
  # so subset the data to align with the levels where the MALR was computed
  ctp_prs = pressure[layer_bot_idx:]
  ctp_tmp = temperature[layer_bot_idx:]

  # Compute the difference between the environmental temperature profile and the MALR
  tdiff = (ctp_tmp-MALR)

  # Create a mask for the layer we want to integrate over
  p_mask = (ctp_prs<=pressure[layer_bot_idx])&(ctp_prs>=pressure[layer_top_idx])

  # Compute the Convective Triggering Potential (CTP) index
  CTP = mpconsts.Rd * units.Quantity(np.trapz(tdiff[p_mask].m,np.log(ctp_prs[p_mask].m)),'K')
# Out:
#   Cell In[183], line 3
#     """ Function for computing the Convective Triggering Potential
#     ^
# IndentationError: unexpected indent

# %%
# output=np.full([nTime,nLat,nLon], np.nan)

# for iLat in tqdm(range(nLat)):
#     for iLon in range(nLon):
#         if np.isfinite(landMask[iLat,iLon]):
#             for iT in range(nTime):
#                 output[iT,iLat,iLon] = calc_ctp(T_invertLev.lev.values * units.hPa,
#                             T_invertLev.isel(time=iT,lat=iLat,lon=iLon).values * units.K,
#                             start_pressure_hpa=-1,bot_pressure_hpa=100.0,top_pressure_hpa=300.0,
#                             interp=False,db=False,plotskewt=False,plotdir="",station="")
# Out:
# 100%|██████████| 42/42 [2:14:44<00:00, 192.49s/it]

# %%
# ctp = xr.DataArray(output, 
#     coords={
#             'time': T_invertLev.time.values,
#             'lat':  T_invertLev.lat.values, 
#             'lon':  T_invertLev.lon.values}, 
#     dims=["time", "lat", "lon"])

# %%
# outdir = '/glade/derecho/scratch/mdfowler/S2S_processed/'
# fileName = outdir+caseNames[0]+'_CTP_JJA_13utc.nc'

# ctp.to_netcdf(path=fileName)

# %%
DS_case0.lat.values
# Out:
# array([10.83769634, 11.78010471, 12.72251309, 13.66492147, 14.60732984,
#        15.54973822, 16.4921466 , 17.43455497, 18.37696335, 19.31937173,
#        20.2617801 , 21.20418848, 22.14659686, 23.08900524, 24.03141361,
#        24.97382199, 25.91623037, 26.85863874, 27.80104712, 28.7434555 ,
#        29.68586387, 30.62827225, 31.57068063, 32.51308901, 33.45549738,
#        34.39790576, 35.34031414, 36.28272251, 37.22513089, 38.16753927,
#        39.10994764, 40.05235602, 40.9947644 , 41.93717277, 42.87958115,
#        43.82198953, 44.76439791, 45.70680628, 46.64921466, 47.59162304,
#        48.53403141, 49.47643979])

# %%
#   Set up to add states to plots
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')


fig, axs = plt.subplots(1,1, figsize=(8, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

axs.plot(250,38,'b*', transform=ccrs.PlateCarree())

# %%
outdir = '/glade/derecho/scratch/mdfowler/S2S_processed/'

ctp_10utc = xr.open_dataset(outdir+caseNames[0]+'_CTP_JJA_10utc.nc')
ctp_13utc = xr.open_dataset(outdir+caseNames[0]+'_CTP_JJA_13utc.nc')


## Around longitude = 110, switch from 13 UTC to 10 UTC. Could also try 105, which is ~longitude of Denver (going with Denver) 
iLon = np.where( (T_invertLev.lon.values>=254) & (T_invertLev.lon.values<=256))[0] 

ctp_combined = ctp_13utc.__xarray_dataarray_variable__.values
ctp_combined[:,:,iLon[0]::] = ctp_10utc.__xarray_dataarray_variable__.values[:,:,iLon[0]::]

ctp = xr.DataArray(ctp_combined, 
    coords={
            'time': T_invertLev.time.values,
            'lat':  T_invertLev.lat.values, 
            'lon':  T_invertLev.lon.values}, 
    dims=["time", "lat", "lon"])

# %%
ctp.isel(time=6).plot()

# %%
ctp_noZeros = ctp.where(ctp.values>=0)

# %%
#   Set up to add states to plots
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')


fig, axs = plt.subplots(1,1, figsize=(12, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

p1 = axs.contourf(ctp_noZeros.lon.values, ctp_noZeros.lat.values, 
            ctp_noZeros.median(dim='time').values,transform=ccrs.PlateCarree() )
fig.colorbar(p1)
axs.set_title('Median of positive CTP days')
# Out:
# Text(0.5, 1.0, 'Median of positive CTP days')

# %%
#   Set up to add states to plots
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')


fig, axs = plt.subplots(1,1, figsize=(12, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

p1 = axs.contourf(ctp.lon.values, ctp.lat.values, 
            ctp.median(dim='time').values,transform=ccrs.PlateCarree() )
fig.colorbar(p1)
axs.set_title('Median of CTP on *all* days')
# Out:
# Text(0.5, 1.0, 'Median of CTP on *all* days')

# %% [markdown]
# ## Compute HIlow

# %%
P_interp = np.append(np.arange(550, 900, 50), np.arange(900,1000, 25))
P_interp = np.append(P_interp, 990)

Q_interp_temp = interpolateToPressure(DS_case0, 'Q', P_interp)

Q_interp = xr.DataArray(Q_interp_temp, 
    coords={
            'time': DS_case0.time.values,
            'lev':  P_interp,
            'lat':  DS_case0.lat.values, 
            'lon':  DS_case0.lon.values}, 
    dims=["time", "lev", "lat", "lon"])

Q_invertLev = Q_interp.isel(lev=slice(None, None, -1))
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-109836' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109820' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109838' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109834' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109837' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109832' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109835' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109830' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109833' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109828' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109831' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109826' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109829' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109824' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109827' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109822' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109825' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109819' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109823' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109817' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109821' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109815' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109818' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109813' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109816' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109811' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109814' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109809' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109812' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109807' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109810' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109805' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109808' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109803' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109806' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109801' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109804' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109799' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109802' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109797' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109800' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109795' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109798' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109740' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109796' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109794' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109793' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109792' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109791' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109790' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109789' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109788' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109787' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109786' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109785' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109784' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109783' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109782' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109781' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109780' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109779' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109778' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109777' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109776' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109775' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109774' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109773' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109772' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109771' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109770' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109769' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109768' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109767' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109766' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109765' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109764' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109763' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109762' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109761' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109760' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109759' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109758' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109757' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109756' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109755' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109754' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109753' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109752' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109751' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109750' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109749' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109748' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109747' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109746' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109743' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109744' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109745' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109739' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109742' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-109741' coro=<Client._gather.<locals>.wait() done, defined at /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py:2208> exception=AllExit()>
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/distributed/client.py", line 2217, in wait
#     raise AllExit()
# distributed.client.AllExit
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/glade/derecho/scratch/mdfowler/tmp/ipykernel_39205/695569846.py", line 4, in <module>
#     Q_interp_temp = interpolateToPressure(DS_case0, 'Q', P_interp)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/derecho/scratch/mdfowler/tmp/ipykernel_39205/2217674269.py", line 49, in interpolateToPressure
#     varInterp = Ngl.vinth2p(DS[varName].values,hyam,hybm,pressGoals,PS,1,p0mb,1,True)
#                             ^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/xarray/core/dataarray.py", line 776, in values
#     return self.variable.values
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/xarray/core/variable.py", line 556, in values
#     return _as_array_or_item(self._data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/xarray/core/variable.py", line 306, in _as_array_or_item
#     data = np.asarray(data)
#            ^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/dask/array/core.py", line 1700, in __array__
#     x = self.compute()
#         ^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/dask/base.py", line 379, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/dask/base.py", line 665, in compute
#     results = schedule(dsk, keys, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/threading.py", line 629, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/threading.py", line 331, in wait
#     gotit = waiter.acquire(True, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1160, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/stack_data/core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/stack_data/utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/stack_data/core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/stack_data/core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/executing/executing.py", line 264, in executing
#     source = cls.for_frame(frame)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/executing/executing.py", line 183, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/executing/executing.py", line 212, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/executing/executing.py", line 223, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#                                                ^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/executing/executing.py", line 163, in __init__
#     self.tree = ast.parse(self.text, filename=filename)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# SystemError: AST constructor recursion depth mismatch (before=129, after=82)

# %%
# %%time

dewpoint_950 = mpc.dewpoint_from_specific_humidity(Q_invertLev.sel(lev=950, method='nearest').lev.values * units.hPa, 
                                                   Q_invertLev.sel(lev=950, method='nearest').values * units(DS_case0.Q.units))

dewpoint_850 = mpc.dewpoint_from_specific_humidity(Q_invertLev.sel(lev=850, method='nearest').lev.values * units.hPa, 
                                                   Q_invertLev.sel(lev=850, method='nearest').values * units(DS_case0.Q.units))
# Out:
# /glade/u/apps/opt/conda/envs/npl-2024a/lib/python3.11/site-packages/metpy/calc/thermo.py:1396: RuntimeWarning: invalid value encountered in log
#   val = np.log(vapor_pressure / mpconsts.nounit.sat_pressure_0c)
# CPU times: user 325 ms, sys: 331 ms, total: 657 ms
# Wall time: 716 ms

# %%
dewpoint_850.units
# Out:
# <Unit('degree_Celsius')>

# %%
# tmpBot =  T_invertLev.sel(lev=950, method='nearest').values * units(DS_case0.T.units) -273.15
# tmpTop =  T_invertLev.sel(lev=850, method='nearest').values * units(DS_case0.T.units) -273.15
tmpBot =  T_invertLev.sel(lev=950, method='nearest').values -273.15
#         [ 2.35412778e+00,  2.11751108e+00,  1.84886143e+00, ...,
#           4.85164049e+00,  4.46409098e+00,  2.84595318e+00],
#         ...,
#         [ 5.28294469e+00,  5.12251687e+00,  4.47875097e+00, ...,
#           1.22450426e+01,  1.08870645e+01,  9.47619559e+00],
#         [ 1.38446171e+01,  1.11970635e+01,  7.39434284e+00, ...,
#           1.06091893e+01,  9.39137918e+00,  8.88160595e+00],
#         [ 2.27646722e+01,  2.12350287e+01,  1.51691807e+01, ...,
#           7.08817355e+00,  7.42665475e+00,  8.09521589e+00]],
#
#        [[ 5.86330375e+00,  4.71709628e+00,  3.61391966e+00, ...,
#           5.53811238e+00,  5.26562709e+00,  5.35115854e+00],
#         [ 6.71153070e+00,  4.72022246e+00,  3.19265273e+00, ...,
#           3.45103192e+00,  4.30798392e+00,  4.13890696e+00],
#         [ 5.14290872e+00,  4.96185993e+00,  3.27191741e+00, ...,
#           3.01484984e+00,  3.15804990e+00,  3.50897940e+00],
#         ...,
#         [ 6.90425332e+00,  7.97965475e+00,  7.74977366e+00, ...,
#           1.49859648e+01,  2.00229565e+01,  2.29511502e+01],
#         [ 8.25254124e+00,  6.58788940e+00,  5.55157685e+00, ...,
#           1.81770908e+01,  1.90774457e+01,  1.79191221e+01],
#         [ 6.23937840e+00,  5.37322812e+00,  4.81712146e+00, ...,
#           1.37723144e+01,  1.09145988e+01,  9.75049692e+00]],
#
#        [[ 4.56604927e+00,  3.26451432e+00,  2.35016931e+00, ...,
#           4.68445081e+00,  4.70512576e+00,  5.36917534e+00],
#         [ 3.96979264e+00,  2.74581391e+00,  2.41798768e+00, ...,
#           4.26823001e+00,  4.32178850e+00,  4.40495755e+00],
#         [ 3.26133983e+00,  2.54360565e+00,  2.92997690e+00, ...,
#           4.30857667e+00,  4.15877844e+00,  3.57284925e+00],
#         ...,
#         [ 5.42191620e+00,  5.16260783e+00,  4.68039233e+00, ...,
#           1.17739074e+00,  6.99161933e-01,  1.19083565e-01],
#         [ 2.32522929e+00,  1.66627985e+00,  1.30625216e+00, ...,
#           7.96469263e+00,  8.20945963e+00,  8.98745605e+00],
#         [-5.71065563e-02,  5.33338438e-02,  5.91251478e-02, ...,
#           8.55473643e+00,  1.28504603e+01,  1.37106539e+01]]])

# %%
HI_low = xr.DataArray(HIlow, 
    coords={
            'time': T_invertLev.time.values,
            'lat':  T_invertLev.lat.values, 
            'lon':  T_invertLev.lon.values}, 
    dims=["time", "lat", "lon"])

# %% [markdown]
# ## CTP-HIlow bins

# %% [markdown]
# First approach follows somewhat less flexible definition of regimes, in Findell & Eltahir part 2: https://journals.ametsoc.org/view/journals/hydr/4/3/1525-7541_2003_004_0570_acosml_2_0_co_2.xml?tab_body=pdf

# %%
DS_main = HI_low.to_dataset(name="HIlow")
DS_main["CTP"] = ctp

# %%
ctpMean = DS_main.CTP.median(dim='time').values
ctpMean[np.where(ctpMean<0)] = np.nan

plt.contourf(landMask*ctpMean)
plt.colorbar()

# %%
plt.contourf(landMask*DS_main.HIlow.mean(dim='time').values)
plt.colorbar()

# %%
category = np.full([len(DS_main.lat.values), len(DS_main.lon.values)], 'NotClassifiedYet')


for iLat in range(len(DS_main.lat.values)):
    for iLon in range(len(DS_main.lon.values)): 
        thisPoint = DS_main.isel(lat=iLat,lon=iLon)
        nDays     = len(thisPoint.time.values)

        # Confirm we have CTP values (over land)
        if np.all(np.isfinite(thisPoint.CTP.values)==True):
            iAtmControl = np.where((thisPoint.CTP.values<=0) | (thisPoint.HIlow.values<=5) | (thisPoint.HIlow.values>=15) )[0]
            iWetRegime  = np.where((thisPoint.CTP.values>0) & (thisPoint.HIlow.values>5) &  (thisPoint.HIlow.values<10))[0]
            iDryRegime  = np.where((thisPoint.CTP.values>0) & (thisPoint.HIlow.values>=10) &  (thisPoint.HIlow.values<15))[0]

            nDays_atm = len(iAtmControl)
            nDays_other = nDays-nDays_atm

            if len(iAtmControl)>=np.floor(nDays*0.8):
                category[iLat,iLon]='AtmControl'
            elif len(iWetRegime)>=np.floor(nDays_other*0.5):
                category[iLat,iLon]='Positive_wet'
            elif len(iDryRegime)>=np.floor(nDays_other*0.5):
                category[iLat,iLon]='Negative_dry'

# %%
coded_array = np.full([len(DS_main.lat.values), len(DS_main.lon.values)], np.nan)
coded_array[np.where(category=='AtmControl')]   = 1
coded_array[np.where(category=='Positive_wet')] = 2
coded_array[np.where(category=='Negative_dry')] = 3

# %%
fig, axs = plt.subplots(1,1, figsize=(12, 3), 
                        subplot_kw={'projection':ccrs.PlateCarree()})

## Set up the map with boundaries, limited extent, etc.
axs.set_extent([230,305,22,49], crs=ccrs.PlateCarree())

axs.coastlines(linewidth=0.5,edgecolor='0.25')
axs.add_feature(cfeature.BORDERS,linewidth=0.5,edgecolor='0.25') 
axs.add_feature(states_provinces,edgecolor='k',linewidth=0.5) 

# axs[0].plot(np.ones(29)*249, np.arange(22,51), color='red', transform=ccrs.PlateCarree())
axs.plot(np.ones(29)*254, np.arange(22,51), color='red', transform=ccrs.PlateCarree())

p1 = axs.pcolormesh(ctp.lon.values, ctp.lat.values, 
            coded_array,transform=ccrs.PlateCarree(), cmap='brg' )
c1 = fig.colorbar(p1)
axs.set_title('CTP-HIlow classification')
# Out:
# Text(0.5, 1.0, 'CTP-HIlow classification')

# %%
a = DS_main.sel(lat=35, lon=250, method='nearest')

# %%
landMatters = DS_main.where(DS_main.CTP>0)
landMatters = landMatters.where((landMatters.HIlow>=5) & (landMatters.HIlow<=15))

wetSoilAdv = landMatters.where( (landMatters.HIlow<=10) )
drySoilAdv = landMatters.where( (landMatters.HIlow>=10) )

# %%
plt.scatter(a.CTP.values, a.HIlow.values)
plt.xlim(-200,600)
plt.ylim(0,60)

plt.axvline(0, color='k')
plt.axhline(15, color='k')
plt.axhline(5, color='k')

# %%
i_atmControl = np.where()

# %%
HI_low
# Out:
# <xarray.DataArray (time: 2300, lat: 42, lon: 97)>
# array([[[ 9.27935027e+00,  7.22973085e+00,  6.39311782e+00, ...,
#           6.24484126e+00,  6.25566101e+00,  6.08338476e+00],
