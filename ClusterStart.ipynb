# %% [markdown]
# This builds on code from Abby Jaye!

# %%
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client
import warnings
warnings.filterwarnings("ignore")

# %%
cluster = PBSCluster(
    project='P93300041',
    cores = 1,
    memory = '4GB',
    processes = 1,
    local_directory = '/glade/derecho/scratch/mdfowler/dask/pbs.$PBS_JOBID/dask/spill',
    resource_spec = 'select=1:ncpus=1:mem=4',
    queue = 'casper',
    walltime = '04:00:00',
    interface = 'ext'
)

# %%
cluster.scale(jobs=8)

# %%
client = Client(cluster)
client.wait_for_workers(8)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 client = Client(cluster)
# ----> 2 client.wait_for_workers(8)
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/site-packages/distributed/client.py:1537, in Client.wait_for_workers(self, n_workers, timeout)
#    1532     raise ValueError(
#    1533         f"`n_workers` must be a positive integer. Instead got {n_workers}."
#    1534     )
#    1536 if self.cluster and hasattr(self.cluster, "wait_for_workers"):
# -> 1537     return self.cluster.wait_for_workers(n_workers, timeout)
#    1539 return self.sync(self._wait_for_workers, n_workers, timeout=timeout)
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/site-packages/distributed/deploy/cluster.py:636, in Cluster.wait_for_workers(self, n_workers, timeout)
#     632 if not isinstance(n_workers, int) or n_workers < 1:
#     633     raise ValueError(
#     634         f"`n_workers` must be a positive integer. Instead got {n_workers}."
#     635     )
# --> 636 return self.sync(self._wait_for_workers, n_workers, timeout=timeout)
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/site-packages/distributed/utils.py:364, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     362     return future
#     363 else:
# --> 364     return sync(
#     365         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     366     )
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/site-packages/distributed/utils.py:437, in sync(loop, func, callback_timeout, *args, **kwargs)
#     435 else:
#     436     while not e.is_set():
# --> 437         wait(10)
#     439 if error is not None:
#     440     raise error
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/site-packages/distributed/utils.py:426, in sync.<locals>.wait(timeout)
#     424 def wait(timeout: float | None) -> bool:
#     425     try:
# --> 426         return e.wait(timeout)
#     427     except KeyboardInterrupt:
#     428         loop.add_callback(cancel)
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /glade/u/apps/opt/conda/envs/npl-2024b/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
client
# Out:
# <Client: 'tcp://128.117.208.109:42179' processes=0 threads=0, memory=0 B>

# %%
print(cluster.job_script())
# Out:
# #!/usr/bin/env bash
#
# #PBS -N dask-worker
# #PBS -q casper
# #PBS -A P93300041
# #PBS -l select=1:ncpus=1:mem=4
# #PBS -l walltime=04:00:00
#
# /glade/u/apps/opt/conda/envs/npl-2024b/bin/python -m distributed.cli.dask_worker tcp://128.117.208.109:42179 --name dummy-name --nthreads 1 --memory-limit 3.73GiB --nanny --death-timeout 60 --local-directory /glade/derecho/scratch/mdfowler/dask/pbs.$PBS_JOBID/dask/spill --interface ext

# %%
cluster.dashboard_link
# Out:
# 'https://jupyterhub.hpc.ucar.edu/stable/user/mdfowler/proxy/8787/status'

# %%
cluster.close()
